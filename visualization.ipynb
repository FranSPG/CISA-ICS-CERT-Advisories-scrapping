# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('icsa.csv', index_col=0)

# %%
df.head(3)
# Out:
#         icsa_code                                                      URL  \
# 0  ICSA-21-147-01  https://us-cert.cisa.gov//ics/advisories/icsa-21-147-01
# 1  ICSA-21-147-02  https://us-cert.cisa.gov//ics/advisories/icsa-21-147-02
# 2  ICSA-21-147-03  https://us-cert.cisa.gov//ics/advisories/icsa-21-147-03
#
#    YEAR  \
# 0    21
# 1    21
# 2    21
#
#                                                                                          CVES  \
# 0                                                                          ['CVE-2020-36244']
# 1                                                                           ['CVE-2021-3156']
# 2  ['CVE-2021-27451', 'CVE-2021-27445', 'CVE-2021-27453', 'CVE-2021-27449', 'CVE-2021-27447']
#
#                                                                                                                                                                                                                                                                                                                                      CVES_URL  \
# 0                                                                                                                                                                                                                                                                          ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2020-36244']
# 1                                                                                                                                                                                                                                                                           ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-3156']
# 2  ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-27447', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-27451', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-27453', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-27449', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-27445']
#
#                                     ATTENTION  \
# 0  Exploitable remotely/low attack complexity
# 1                       Low attack complexity
# 2  Exploitable remotely/low attack complexity
#
#                                                            VENDOR   EQUIPMENT  \
# 0                                                 GENIVI Alliance  DLT-Daemon
# 1  Sensormatic Electronics, LLC, a subsidiary of Johnson Controls   VideoEdge
# 2                                                       Mesa Labs   AmegaView
#
#                                                                                                                                                                                                                                                       VULNERABILITIES  \
# 0  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize VPN is only as secure as its connected devices.
# 1  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize VPN is only as secure as its connected devices.
# 2  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize VPN is only as secure as its connected devices.
#
#                        CRITICAL INFRAESTRUCTURE SECTOR  \
# 0                               Critical Manufacturing
# 1                               Critical Manufacturing
# 2   Healthcare and Public Health, Food and Agriculture
#
#   COUNTRIES\/AREAS DEPLOYED COMPANY HEADQUARTERS LOCATION  \
# 0                 Worldwide                 United States
# 1                 Worldwide                       Ireland
# 2             United States                 United States
#
#                                                     CWES
# 0                                            ['CWE-122']
# 1                                            ['CWE-193']
# 2  ['CWE-77', 'CWE-287', 'CWE-288', 'CWE-77', 'CWE-269']

# %%
df['YEAR'].value_counts()
# Out:
# 20    248
# 19    224
# 18    224
# 17    190
# 21    144
# 16    141
# 15    134
# 14    101
# 13     84
# 12     81
# 11     71
# 10     20
# Name: YEAR, dtype: int64

# %%
df['VENDOR'].value_counts()[:4]
# Out:
# Siemens                                                                                            302
# Rockwell Automation                                                                                283
# Upgrade to a newer system that is supported by the vendor.                                         134
# Database and web interfaces to customers, vendors, and enterprise resource planning interfaces;    102
# Name: VENDOR, dtype: int64

# %%
df.loc[(df['VENDOR'] == 'Siemens') &
# 849                  Exploitable from an adjacent network/low skill level to exploit
# 850                  Exploitable from an adjacent network/low skill level to exploit
# 864   Exploitable remotely/low skill level to exploit/public exploits are available.
# 865   Exploitable remotely/low skill level to exploit/public exploits are available.
# 866   Exploitable remotely/low skill level to exploit/public exploits are available.
# 869                                  Exploitable remotely/low skill level to exploit
# 870                                  Exploitable remotely/low skill level to exploit
# 871                                  Exploitable remotely/low skill level to exploit
# 872                                  Exploitable remotely/low skill level to exploit
# 873                                  Exploitable remotely/low skill level to exploit
# 972                  Exploitable from an adjacent network/low skill level to exploit
# 973                  Exploitable from an adjacent network/low skill level to exploit
# 974                  Exploitable from an adjacent network/low skill level to exploit
# 975                  Exploitable from an adjacent network/low skill level to exploit
# 976                  Exploitable from an adjacent network/low skill level to exploit
# 977                  Exploitable from an adjacent network/low skill level to exploit
# 978                  Exploitable from an adjacent network/low skill level to exploit
# 979                  Exploitable from an adjacent network/low skill level to exploit
# 980                  Exploitable from an adjacent network/low skill level to exploit
# 981                  Exploitable from an adjacent network/low skill level to exploit
# 982                  Exploitable from an adjacent network/low skill level to exploit
# 983                  Exploitable from an adjacent network/low skill level to exploit
# 984                  Exploitable from an adjacent network/low skill level to exploit
# 985                  Exploitable from an adjacent network/low skill level to exploit
# 986                  Exploitable from an adjacent network/low skill level to exploit
# 987                  Exploitable from an adjacent network/low skill level to exploit
# 988                  Exploitable from an adjacent network/low skill level to exploit
# 1014                                 Remotely exploitable/low skill level to exploit
# 1015                                 Remotely exploitable/low skill level to exploit
# 1016                                 Remotely exploitable/low skill level to exploit
# 1017                                 Remotely exploitable/low skill level to exploit
# 1018                                 Remotely exploitable/low skill level to exploit
# 1019                                 Remotely exploitable/low skill level to exploit
# 1020                                 Remotely exploitable/low skill level to exploit
# 1021                                 Remotely exploitable/low skill level to exploit
# 1022                                 Remotely exploitable/low skill level to exploit
# 1023                                 Remotely exploitable/low skill level to exploit
# 1024                                 Remotely exploitable/low skill level to exploit
# 1025                                 Remotely exploitable/low skill level to exploit
# 1027                                 Remotely exploitable/low skill level to exploit
# 1028                                 Remotely exploitable/low skill level to exploit
# 1029                                 Remotely exploitable/low skill level to exploit
# 1030                                 Remotely exploitable/low skill level to exploit
# 1031                                 Remotely exploitable/low skill level to exploit
#
#        VENDOR  \
# 112   Siemens
# 113   Siemens
# 205   Siemens
# 240   Siemens
# 274   Siemens
# 845   Siemens
# 848   Siemens
# 849   Siemens
# 850   Siemens
# 864   Siemens
# 865   Siemens
# 866   Siemens
# 869   Siemens
# 870   Siemens
# 871   Siemens
# 872   Siemens
# 873   Siemens
# 972   Siemens
# 973   Siemens
# 974   Siemens
# 975   Siemens
# 976   Siemens
# 977   Siemens
# 978   Siemens
# 979   Siemens
# 980   Siemens
# 981   Siemens
# 982   Siemens
# 983   Siemens
# 984   Siemens
# 985   Siemens
# 986   Siemens
# 987   Siemens
# 988   Siemens
# 1014  Siemens
# 1015  Siemens
# 1016  Siemens
# 1017  Siemens
# 1018  Siemens
# 1019  Siemens
# 1020  Siemens
# 1021  Siemens
# 1022  Siemens
# 1023  Siemens
# 1024  Siemens
# 1025  Siemens
# 1027  Siemens
# 1028  Siemens
# 1029  Siemens
# 1030  Siemens
# 1031  Siemens
#
#                                                                                                                                            EQUIPMENT  \
# 112                                                                                                                              Industrial Products
# 113                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 205                                                                                                                                            LOGO!
# 240                                                                                                SCALANCE W1750D, M800, S615, and RUGGEDCOM RM1224
# 274                                                                                                                                          SIMATIC
# 845                                                                                                                              Industrial Products
# 848                                                                                                                              Industrial Products
# 849                                                                                                                              Industrial Products
# 850                                                                                                                              Industrial Products
# 864                                                                                              SCALANCE, SIMATIC, RUGGEDCOM, and SINAMICS Products
# 865                                                                                              SCALANCE, SIMATIC, RUGGEDCOM, and SINAMICS Products
# 866                                                                                              SCALANCE, SIMATIC, RUGGEDCOM, and SINAMICS Products
# 869                                                                                                                                    SIMATIC PCS 7
# 870                                                                                                                                    SIMATIC PCS 7
# 871                                                                                                                                    SIMATIC PCS 7
# 872                                                                                                                                    SIMATIC PCS 7
# 873                                                                                                                                    SIMATIC PCS 7
# 972                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 973                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 974                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 975                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 976                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 977                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 978                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 979                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 980                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 981                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 982                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 983                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 984                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 985                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 986                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 987                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 988                                                                            Devices using the PROFINET Discovery and Configuration Protocol (DCP)
# 1014                                                                                                                                         SIMATIC
# 1015                                                                                                                                         SIMATIC
# 1016                                                                                                                                         SIMATIC
# 1017  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1018  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1019  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1020  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1021  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1022  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1023  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1024  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1025  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1027  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1028  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1029  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1030  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
# 1031  Users are advised to exercise diligence in implementing a physical asset management program that involves tracking and inventorying equipment.
#
#                                                                                                                                                                                                                                                                    VULNERABILITIES  \
# 112             When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize VPN is only as secure as the connected devices.
# 113                                                                                                                                                                                                                                                      Improper Input Validation
# 205                                                                                                                                                                                                                        Insufficiently Protected Credentials, Man-in-the-Middle
# 240   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 274                                                                                                                                                                                                                          Improper restriction of XML external entity reference
# 845   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 848   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 849   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 850   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 864                                                                                                                                                                                                                                                              Security Features
# 865   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 866   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 869   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 870   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 871   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 872   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 873   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 972   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 973   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 974   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 975   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 976   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 977   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 978   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 979   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 980   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 981   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 982   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 983   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 984   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 985   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 986   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 987   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 988   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1014  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1015  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1016  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1017  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1018  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1019  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1020  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1021  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1022  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1023  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1024  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1025  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1027  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1028  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1029  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1030  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1031  When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
#
#                                                                                                                                       CRITICAL INFRAESTRUCTURE SECTOR  \
# 112                        Critical Infrastructure Sectors: Commercial Facilities, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 113                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 205                                                                                                                     Commercial Facilities, Transportation Systems
# 240                                    Chemical, Energy, Food and Agriculture, Healthcare and Public Health, Transportation Systems, and Water and Wastewater Systems
# 274                                                                                              Chemical, Energy, Food and Agriculture, Water and Wastewater Systems
# 845                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 848                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 849                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 850                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 864   Critical Infrastructure Sectors: Chemical, Energy, Food and Agriculture, Healthcare and Public Health, Transportation Systems, and Water and Wastewater Systems
# 865   Critical Infrastructure Sectors: Chemical, Energy, Food and Agriculture, Healthcare and Public Health, Transportation Systems, and Water and Wastewater Systems
# 866   Critical Infrastructure Sectors: Chemical, Energy, Food and Agriculture, Healthcare and Public Health, Transportation Systems, and Water and Wastewater Systems
# 869                                                                                          Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 870                                                                                          Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 871                                                                                          Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 872                                                                                          Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 873                                                                                          Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 972                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 973                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 974                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 975                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 976                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 977                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 978                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 979                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 980                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 981                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 982                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 983                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 984                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 985                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 986                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 987                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 988                                                                      Chemical, Critical Manufacturing, Energy, Food and Agriculture, Water and Wastewater Systems
# 1014                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1015                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1016                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1017                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1018                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1019                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1020                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1021                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1022                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1023                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1024                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1025                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1027                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1028                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1029                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1030                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
# 1031                                                                                         Chemical, Energy, Food and Agriculture, and Water and Wastewater Systems
#
#                 COUNTRIES\/AREAS DEPLOYED  \
# 112   Countries/Areas Deployed: Worldwide
# 113                             Worldwide
# 205                             Worldwide
# 240                             Worldwide
# 274                             Worldwide
# 845                             Worldwide
# 848                             Worldwide
# 849                             Worldwide
# 850                             Worldwide
# 864   Countries/Areas Deployed: Worldwide
# 865   Countries/Areas Deployed: Worldwide
# 866   Countries/Areas Deployed: Worldwide
# 869                             Worldwide
# 870                             Worldwide
# 871                             Worldwide
# 872                             Worldwide
# 873                             Worldwide
# 972                             Worldwide
# 973                             Worldwide
# 974                             Worldwide
# 975                             Worldwide
# 976                             Worldwide
# 977                             Worldwide
# 978                             Worldwide
# 979                             Worldwide
# 980                             Worldwide
# 981                             Worldwide
# 982                             Worldwide
# 983                             Worldwide
# 984                             Worldwide
# 985                             Worldwide
# 986                             Worldwide
# 987                             Worldwide
# 988                             Worldwide
# 1014                            Worldwide
# 1015                            Worldwide
# 1016                            Worldwide
# 1017                            Worldwide
# 1018                            Worldwide
# 1019                            Worldwide
# 1020                            Worldwide
# 1021                            Worldwide
# 1022                            Worldwide
# 1023                            Worldwide
# 1024                            Worldwide
# 1025                            Worldwide
# 1027                            Worldwide
# 1028                            Worldwide
# 1029                            Worldwide
# 1030                            Worldwide
# 1031                            Worldwide
#
#                COMPANY HEADQUARTERS LOCATION  \
# 112   Company Headquarters Location: Germany
# 113                                  Germany
# 205                                  Germany
# 240                                  Germany
# 274                                  Germany
# 845                                  Germany
# 848                                  Germany
# 849                                  Germany
# 850                                  Germany
# 864   Company Headquarters Location: Germany
# 865   Company Headquarters Location: Germany
# 866   Company Headquarters Location: Germany
# 869                                  Germany
# 870                                  Germany
# 871                                  Germany
# 872                                  Germany
# 873                                  Germany
# 972                                  Germany
# 973                                  Germany
# 974                                  Germany
# 975                                  Germany
# 976                                  Germany
# 977                                  Germany
# 978                                  Germany
# 979                                  Germany
# 980                                  Germany
# 981                                  Germany
# 982                                  Germany
# 983                                  Germany
# 984                                  Germany
# 985                                  Germany
# 986                                  Germany
# 987                                  Germany
# 988                                  Germany
# 1014                                 Germany
# 1015                                 Germany
# 1016                                 Germany
# 1017                                 Germany
# 1018                                 Germany
# 1019                                 Germany
# 1020                                 Germany
# 1021                                 Germany
# 1022                                 Germany
# 1023                                 Germany
# 1024                                 Germany
# 1025                                 Germany
# 1027                                 Germany
# 1028                                 Germany
# 1029                                 Germany
# 1030                                 Germany
# 1031                                 Germany
#
#                                              CWES
# 112                                            []
# 113                                            []
# 205                        ['CWE-522', 'CWE-300']
# 240                        ['CWE-400', 'CWE-119']
# 274                                            []
# 845                                            []
# 848                                            []
# 849                                            []
# 850                                            []
# 864                                            []
# 865                                            []
# 866   ['EXPLOITABILITY', 'EXPLOIT', 'DIFFICULTY']
# 869                                            []
# 870                                            []
# 871                                            []
# 872                                            []
# 873                                            []
# 972                                            []
# 973                                            []
# 974                                            []
# 975                                            []
# 976                                            []
# 977                                            []
# 978                                            []
# 979                                            []
# 980                                            []
# 981                                            []
# 982                                            []
# 983                                            []
# 984                                            []
# 985                                            []
# 986                                            []
# 987                                            []
# 988                                            []
# 1014                                           []
# 1015                                           []
# 1016                                           []
# 1017  ['EXPLOITABILITY', 'EXPLOIT', 'DIFFICULTY']
# 1018  ['EXPLOITABILITY', 'EXPLOIT', 'DIFFICULTY']
# 1019                                           []
# 1020                                           []
# 1021  ['EXPLOITABILITY', 'EXPLOIT', 'DIFFICULTY']
# 1022                                           []
# 1023                                           []
# 1024                                           []
# 1025                                           []
# 1027                                           []
# 1028                                           []
# 1029                                           []
# 1030                                           []
# 1031  ['EXPLOITABILITY', 'EXPLOIT', 'DIFFICULTY']

# %%
df.shape
# Out:
# (1657, 11)

# %%
df.sample(3)
# Out:
#             icsa_code  \
# 322   ICSMA-20-170-05
# 903    ICSA-17-250-02
# 1481   ICSA-13-067-01
#
#                                                            URL  YEAR  \
# 322   https://us-cert.cisa.gov//ics/advisories/icsma-20-170-05    20
# 903    https://us-cert.cisa.gov//ics/advisories/ICSA-17-250-02    17
# 1481   https://us-cert.cisa.gov//ics/advisories/ICSA-13-067-01    13
#
#                                                                                             CVES  \
# 322   ['CVE-2019-18248', 'CVE-2019-18252', 'CVE-2019-18256', 'CVE-2019-18254', 'CVE-2019-18246']
# 903                                                                            ['CVE-2013-6466']
# 1481                                                                          ['CVE-2013-16272']
#
#                                                                                                                                                                                                                                                                                                                                         CVES_URL  \
# 322   ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-18246', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-18248', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-18252', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-18254', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-18256']
# 903                                                                                                                                                                                                                                                                            ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2013-6466']
# 1481                                                                                                                                                                                                                                                                                                                                          []
#
#                                                          ATTENTION  \
# 322   Exploitable with adjacent access/low skill level to exploit
# 903             Exploitable remotely/public exploits are available
# 1481               Exploitable remotely/low skill level to exploit
#
#                             VENDOR  \
# 322                      BIOTRONIK
# 903            Rockwell Automation
# 1481  Wind River, General Electric
#
#                                                   EQUIPMENT  \
# 322   CardioMessenger II-S T-Line, CardioMessenger II-S GSM
# 903     Stratix 5100 Wireless Access Point/Workgroup Bridge
# 1481                                         VxWorks, D20MX
#
#                                                                                                                                                                                                                                                                    VULNERABILITIES  \
# 322                                                                                                                      Improper Authentication, Cleartext Transmission of Sensitive Information, Missing Encryption of Sensitive Data, Storing Passwords in a Recoverable Format
# 903   When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
# 1481  When remote access is required, use secure methods, such as virtual private networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize that VPN is only as secure as the connected devices.
#
#                                     CRITICAL INFRAESTRUCTURE SECTOR  \
# 322                                    Healthcare and Public Health
# 903    Critical Manufacturing, Energy, Water and Wastewater Systems
# 1481   Critical Manufacturing, Energy, Water and Wastewater Systems
#
#      COUNTRIES\/AREAS DEPLOYED COMPANY HEADQUARTERS LOCATION  \
# 322                  Worldwide                       Germany
# 903                  Worldwide                 United States
# 1481                 Worldwide                 United States
#
#                                                          CWES
# 322   ['CWE-287', 'CWE-319', 'CWE-287', 'CWE-311', 'CWE-257']
# 903                                                        []
# 1481                                                       []

# %%
df[df['icsa_code'].str.contains('ICSMA')].iloc[:3]
# Out:
#            icsa_code  \
# 91   ICSMA-19-080-01
# 93   ICSMA-21-084-01
# 107  ICSMA-17-017-02
#
#                                                           URL  YEAR  \
# 91   https://us-cert.cisa.gov//ics/advisories/ICSMA-19-080-01    19
# 93   https://us-cert.cisa.gov//ics/advisories/icsma-21-084-01    21
# 107  https://us-cert.cisa.gov//ics/advisories/icsma-17-017-02    17
#
#                                    CVES  \
# 91   ['CVE-2019-6540', 'CVE-2019-6538']
# 93                   ['CVE-2021-27456']
# 107  ['CVE-2016-8375', 'CVE-2016-9355']
#
#                                                                                                                                CVES_URL  \
# 91   ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-6538', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2019-6540']
# 93                                                                   ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2021-27456']
# 107  ['http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2016-8375', 'http://web.nvd.nist.gov/view/vuln/detail?vulnId=CVE-2016-9355']
#
#                                                   ATTENTION  \
# 91   Exploitable with adjacent access/low attack complexity
# 93                               Low skill level to exploit
# 107                              Low skill level to exploit
#
#                                  VENDOR  \
# 91                            Medtronic
# 93                              Philips
# 107  Becton, Dickinson and Company (BD)
#
#                                                                                                                                                                                                                EQUIPMENT  \
# 91                                                                                             MyCareLink Monitor, CareLink Monitor, CareLink 2090 Programmer, specific Medtronic implanted cardiac devices listed below
# 93                                                                                                                                                                                                  Gemini PET/CT Family
# 107  BD recommends hospitals create dedicated medical device wireless networks that only house medical equipment with wireless cards. This could potentially reduce the impact to other devices on the hospital network.
#
#                                                                                                                                                                                                                                                                VULNERABILITIES  \
# 91                                                                                                                                                                                                    Improper Access Control, Cleartext Transmission of Sensitive Information
# 93   When remote access is required, use secure methods, such as virtual private networks (VPNs), recognizing that VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize a VPN is only as secure as the connected devices.
# 107         When remote access is required, use secure methods, such as Virtual Private Networks (VPNs), recognizing VPNs may have vulnerabilities and should be updated to the most current version available. Also recognize VPN is only as secure as the connected devices.
#
#     CRITICAL INFRAESTRUCTURE SECTOR COUNTRIES\/AREAS DEPLOYED  \
# 91     Healthcare and Public Health                 Worldwide
# 93     Healthcare and Public Health                 Worldwide
# 107    Healthcare and Public Health                 Worldwide
#
#     COMPANY HEADQUARTERS LOCATION                    CWES
# 91                        Ireland  ['CWE-284', 'CWE-319']
# 93                    Netherlands             ['CWE-921']
# 107                 United States  ['CWE-522', 'CWE-254']
